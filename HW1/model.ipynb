# %%
#!/usr/bin/env python
# coding: utf-8

# import packages
# Note: You cannot import any other packages!
import numpy as np
import matplotlib.pyplot as plt
import csv
import math
import random



# Global attributes
# Do not change anything here except TODO 1 
StudentID = '108062213' # TODO 1 : Fill your student ID here
input_dataroot = 'input.csv' # Please name your input csv file as 'input.csv'
output_dataroot = StudentID + '_basic_prediction.csv' # Output file will be named as '[StudentID]_basic_prediction.csv'

input_datalist =  [] # Initial datalist, saved as numpy array
output_datalist =  [] # Your prediction, should be 20 * 2 matrix and saved as numpy array
                      # The format of each row should be [Date, TSMC_Price_Prediction] 
                      # e.g. ['2021/10/15', 512]

# You can add your own global attributes here

validation_data = np.array([])
train_data_60 = np.array([])
train_data_120 = np.array([])
train_data_168 = np.array([])

model = []

# Read input csv to datalist
with open(input_dataroot, newline='') as csvfile:
    input_datalist = np.array(list(csv.reader(csvfile)))

# From TODO 2 to TODO 6, you can declare your own input parameters, local attributes and return parameters
    
def SplitData():
# TODO 2: Split data, 2021/10/15 ~ 2021/11/11 for testing data, and the other for training data and validation data 
    testing_data = input_datalist[189:]
    
    validation_data = input_datalist[168:189]
    
    train_data_60 = input_datalist[108:168]
    train_data_120 = input_datalist[48:168]
    train_data_168 = input_datalist[0:168]
    
    
    return testing_data


def PreprocessData(data):
# TODO 3: Preprocess your data  e.g. split datalist to x_datalist and y_datalist
    x_datalist = []
    y_datalist = []
    ret = []
    
    for i in range(0,len(data)):
        x_datalist.append(int(data[i][1]))
        y_datalist.append(int(data[i][2]))
        
    ret.append(x_datalist)
    ret.append(y_datalist)
    
    return ret
        

def Regression(train):
# TODO 4: Implement regression
    x = np.array(PreprocessData(train)[0])
    y = np.array(PreprocessData(train)[1])
    
    
    x_vec = np.concatenate( (np.ones( (x.shape[0], 1) ), x[:,np.newaxis]), axis=1)
    y_vec = y[:,np.newaxis]
    
    print(x_vec)
    
    w_vec = np.matmul( np.matmul( np.linalg.inv( np.matmul(x_vec.T,x_vec) ),x_vec.T ),y_vec )

    
    return w_vec


def CountLoss(model):
# TODO 5: Count loss of training and validation data
    #MSE
    estimate = []
    beta = Regression(model)
    estimate = beta[0]+beta[1]*validation_data
    loss = (1/estimate.size) * np.sum((estimate-theory)**2)
    
    return loss


def MakePrediction(model, target):
# TODO 6: Make prediction of testing data 
    w = Regression(model)
    y = w[0]+w[1]*target
    
    return y



# TODO 7: Call functions of TODO 2 to TODO 6, train the model and make prediction
test = []
test = SplitData()

day60 = CountLoss(Regression(train_data_60))
day120 = CountLoss(Regression(train_data_120))
day168 = CountLoss(Regression(train_data_156))



best_model = max(day60, day120, day156)
if(best_model==day60):
    model = train_data_60
elif(best_model==day120):
    model = train_data_120
else :
    model = train_data_68
    
MakePrediction(model, test)


# Write prediction to output csv
with open(output_dataroot, 'w', newline='', encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    #writer.writerow(['Date', 'TSMC Price'])
    tsmc = MakePrediction(model, testing_data)
    
    output_datalist = input_datalist
    output_datalist = np.delete(output_datalist, 2, axis=1) #date
    
    for i in range(0,20):
        output_datalist[i,0] = output_datalist[i+189,0]
        output_datalist[i,1] = tsmc[i]
    
    for row in output_datalist:
        writer.writerow(row)
# Out:
# []
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /var/folders/d6/x5by154j52z5mmmcpg2k3mr80000gn/T/ipykernel_13785/1726937796.py in <module>
#     109 test = SplitData()
#     110
# --> 111 day60 = CountLoss(Regression(train_data_60))
#     112 day120 = CountLoss(Regression(train_data_120))
#     113 day168 = CountLoss(Regression(train_data_156))
#
# /var/folders/d6/x5by154j52z5mmmcpg2k3mr80000gn/T/ipykernel_13785/1726937796.py in Regression(train)
#      79     print(x_vec)
#      80
# ---> 81     w_vec = np.matmul( np.matmul( np.linalg.inv( np.matmul(x_vec.T,x_vec) ),x_vec.T ),y_vec )
#      82
#      83
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
# Out:
# []
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /var/folders/d6/x5by154j52z5mmmcpg2k3mr80000gn/T/ipykernel_13785/3359361199.py in <module>
#      23 test = SplitData()
#      24
# ---> 25 day60 = CountLoss(Regression(train_data_60))
#      26 day120 = CountLoss(Regression(train_data_120))
#      27 day156 = CountLoss(Regression(train_data_156))
#
# /var/folders/d6/x5by154j52z5mmmcpg2k3mr80000gn/T/ipykernel_13785/399078135.py in Regression(train)
#      79     print(x_vec)
#      80
# ---> 81     w_vec = np.matmul( np.matmul( np.linalg.inv( np.matmul(x_vec.T,x_vec) ),x_vec.T ),y_vec )
#      82
#      83
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
